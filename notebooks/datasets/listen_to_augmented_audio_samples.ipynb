# %% [markdown]
# # Listen to augmented audio samples

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
os.chdir('../..')
sys.path.insert(1, os.path.join(sys.path[0], '../..'))

# %%
from sslsv.datasets.DataAugmentation import DataAugmentation, DataAugmentationConfig

# %%
import numpy as np
import soundfile as sf
from pathlib import Path
import IPython.display as ipd

# %%
augmentation = DataAugmentation(DataAugmentationConfig(), Path('data/'))

# %%
sample_path = 'data/voxceleb1/id10270/5r0dWxy17C8/00001.wav'

data, sr = sf.read(sample_path)
data = data.reshape((1, -1)).astype(np.float32)

ipd.display(ipd.Audio(data, rate=sr))
ipd.display(ipd.Audio(augmentation(data), rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 7
#       4 data = data.reshape((1, -1)).astype(np.float32)
#       6 ipd.display(ipd.Audio(data, rate=sr))
# ----> 7 ipd.display(ipd.Audio(augmentation(data), rate=sr))
#
# File /media/volume/AudioUnlearnData1/sslsv/sslsv/datasets/DataAugmentation.py:202, in DataAugmentation.__call__(self, audio)
#     200     audio = self.add_noise(audio)
#     201 elif self.config.strategy == DataAugmentationStrategyEnum.BOTH:
# --> 202     audio = self.reverberate(audio)
#     203     audio = self.add_noise(audio)
#     204 elif self.config.strategy == DataAugmentationStrategyEnum.ALL:
#
# File /media/volume/AudioUnlearnData1/sslsv/sslsv/datasets/DataAugmentation.py:109, in DataAugmentation.reverberate(self, audio)
#      98 def reverberate(self, audio: np.ndarray) -> np.ndarray:
#      99     """
#     100     Apply reverberation to an audio signal using a randomly sampled
#     101     Room Impulse Response (RIR).
#    (...)    107         np.ndarray: Output audio.
#     108     """
# --> 109     rir_file = random.choice(self.rir_files)
#     111     rir, fs = read_audio(rir_file)
#     112     rir = rir.reshape((1, -1)).astype(np.float32)
#
# File /media/volume/AudioUnlearnData1/miniconda3/envs/sslsv/lib/python3.13/random.py:351, in Random.choice(self, seq)
#     348 # As an accommodation for NumPy, we don't use "if not seq"
#     349 # because bool(numpy.array()) raises a ValueError.
#     350 if not len(seq):
# --> 351     raise IndexError('Cannot choose from an empty sequence')
#     352 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence
