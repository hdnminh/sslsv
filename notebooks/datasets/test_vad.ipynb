# %% [markdown]
# # Test Voice Activity Detection (VAD)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
os.chdir('../..')
sys.path.insert(1, os.path.join(sys.path[0], '../..'))

# %%
import soundfile as sf
import IPython.display as ipd

file = '/media/volume/AudioUnlearnData1/sslsv/data/voxceleb1/id10309/_z_BR0ERa9g/00001.wav'

audio, sr = sf.read(file, dtype='int16')

ipd.display(ipd.Audio(audio, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Add the notebooks/datasets directory to the Python path
sys.path.insert(0, 'notebooks/datasets')
from VAD import VAD

# from notebooks.datasets.VAD import VAD

vad = VAD(threshold=-20)

output = vad.apply(audio, sr)

# %%
import matplotlib.pyplot as plt

def plot_vad(data, titles, sr):
    plt.subplots(len(data), 1, figsize=(20, 10))
    plt.subplots_adjust(hspace=0.5)

    for i in range(len(data)):
        plt.subplot(len(data), 1, i + 1)
        y = data[i]
        x = [i / sr for i in range(0, len(y))]
        plt.plot(x, y)
        plt.gca().set_title(titles[i])

    plt.show()

# %%
plot_vad(
    data=[audio, vad.last_energy, vad.last_vad, output],
    titles=[
        'Input signal',
        'Short time energy',
        'Voice activity detection',
        'Output signal'
    ],
    sr=sr
)

# %%
vad.last_vad.mean()
# Out:
# np.float64(0.29957805907172996)

# %%
audio.shape, output.shape
# Out:
# ((94721,), (28400,))
